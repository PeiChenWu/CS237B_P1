# %%
import argparse, pdb
import numpy as np, tensorflow as tf
from utils import IMG_SIZE, image_generator, LABELS, maybe_makedirs

BATCH_SIZE = 100
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
lr = 0.01


def get_bottleneck_dataset(model, img_dir, img_size):
    # image_generator is of type ImageDataGenerator
    # Find more information here
    # https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator?version=stable
    train_img_gen = image_generator.flow_from_directory(
        img_dir,
        target_size=(img_size, img_size),
        shuffle=False,  # this is important for accessing filenames
        classes=LABELS,
        batch_size=1,
    )

    bottleneck_x_l = []
    bottleneck_y_l = []
    for i in range(train_img_gen.samples):
        ######### Your code starts here #########
        # We want to create a dataset of bottleneck data.
        # You can get the next image input and one-hot encoded label via x_i, y_i = next(train_img_gen)
        # For each iteration append the bottleneck output as well as the label to the respective list
        # bottleneck_x_l -> list of tensors with dimension [1, bottleneck_size]
        # bottleneck_y_l -> list of tensors with dimension [1, num_labels]
        # Fill in the parts indicated by #FILL#. No additional lines are required.
        
        x_i, y_i = next(train_img_gen)
        bottleneck_x_l.append(model(x_i))
        bottleneck_y_l.append(y_i)

        ######### Your code ends here #########

    bottleneck_ds = tf.data.Dataset.from_tensor_slices(
        (np.vstack(bottleneck_x_l), np.vstack(bottleneck_y_l))
    )

    return bottleneck_ds, train_img_gen.samples


def retrain(image_dir):
    # Create the base model from the pre-trained model InceptionV3
    base_model = tf.keras.applications.InceptionV3(
        input_shape=IMG_SHAPE,
        include_top=False,
        pooling="avg",
        weights="imagenet",
    )

    base_model.summary()
    base_model.compile(loss="mse")

    print("Generating Bottleneck Dataset... this may take some minutes.")
    bottleneck_train_ds, num_train = get_bottleneck_dataset(
        base_model, img_dir=image_dir, img_size=IMG_SIZE
    )
    train_batches = (
        bottleneck_train_ds.shuffle(10000).batch(BATCH_SIZE).repeat()
    )
    print("Done generating Bottleneck Dataset")

    ######### Your code starts here #########
    # We want to create a linear classifier which takes the bottleneck data as input
    # 1. Get the size of the bottleneck tensor. Hint: You can get the shape of a tensor via tensor.get_shape().as_list()
    # 2. Define a new tf.keras Model which is a linear classifier
    #   2.1 Define a keras Input (retrain_input)
    #   2.2 Define the trainable layer (retrain_layer)
    #   2.3 Define the activation function (retrain activation)
    #   2.4 Create a new model
    # 3. Define a loss and a evaluation metric
    # Fill in the parts indicated by #FILL#. No additional lines are required.
    
    retrain_input = tf.keras.layers.Input(shape=base_model.output.get_shape().as_list()[1:])
    retrain_layer = tf.keras.layers.Dense(3, activation="softmax", name='classifier')
    retrain_model = tf.keras.Model(inputs=[retrain_input], outputs=retrain_layer(retrain_input))  

    loss = 'categorical_crossentropy'
    metric = 'accuracy'

    ######### Your code ends here #########

    retrain_model.compile(
        optimizer=tf.keras.optimizers.SGD(learning_rate=lr), loss=loss, metrics=[metric]
    )
    retrain_model.summary()

    EPOCHS = 1
    steps_per_epoch = 5000
    tensorboard_callback = tf.keras.callbacks.TensorBoard(
        log_dir="retrain_logs", update_freq="batch"
    )
    retrain_model.fit(
        train_batches,
        epochs=EPOCHS,
        steps_per_epoch=steps_per_epoch,
        callbacks=[tensorboard_callback],
    )

    ######### Your code starts here #########
    # We now want to create the full model using the newly trained classifier
    # Use tensorflow keras Sequential to stack the base_model and the new layers
    # Fill in the parts indicated by #FILL#. No additional lines are required.
    
    #model = tf.keras.Sequential([])
    #model.add(base_model)
    #model.add(retrain_layer)
    
    model=tf.keras.Sequential([base_model, retrain_layer])
    
    ######### Your code ends here #########

    model.compile(loss=loss, metrics=[metric])

    maybe_makedirs("trained_models")
    model.save("trained_models/trained.h5")


if __name__ == "__main__":
    writer = tf.summary.create_file_writer("retrain_logs")
    tf.summary.trace_on()
    parser = argparse.ArgumentParser()
    parser.add_argument("--image_dir", type=str)
    FLAGS, _ = parser.parse_known_args()
    #retrain(FLAGS.image_dir)
    retrain('datasets/train')
    with writer.as_default():
        tf.summary.trace_export("retrain", step=0)
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_26 (InputLayer)          [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_1598 (Conv2D)           (None, 149, 149, 32  864         ['input_26[0][0]']
#                                 )
#
#  batch_normalization_1598 (Batc  (None, 149, 149, 32  96         ['conv2d_1598[0][0]']
#  hNormalization)                )
#
#  activation_1598 (Activation)   (None, 149, 149, 32  0           ['batch_normalization_1598[0][0]'
#                                 )                                ]
#
#  conv2d_1599 (Conv2D)           (None, 147, 147, 32  9216        ['activation_1598[0][0]']
#                                 )
#
#  batch_normalization_1599 (Batc  (None, 147, 147, 32  96         ['conv2d_1599[0][0]']
#  hNormalization)                )
#
#  activation_1599 (Activation)   (None, 147, 147, 32  0           ['batch_normalization_1599[0][0]'
#                                 )                                ]
#
#  conv2d_1600 (Conv2D)           (None, 147, 147, 64  18432       ['activation_1599[0][0]']
#                                 )
#
#  batch_normalization_1600 (Batc  (None, 147, 147, 64  192        ['conv2d_1600[0][0]']
#  hNormalization)                )
#
#  activation_1600 (Activation)   (None, 147, 147, 64  0           ['batch_normalization_1600[0][0]'
#                                 )                                ]
#
#  max_pooling2d_68 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_1600[0][0]']
#  )
#
#  conv2d_1601 (Conv2D)           (None, 73, 73, 80)   5120        ['max_pooling2d_68[0][0]']
#
#  batch_normalization_1601 (Batc  (None, 73, 73, 80)  240         ['conv2d_1601[0][0]']
#  hNormalization)
#
#  activation_1601 (Activation)   (None, 73, 73, 80)   0           ['batch_normalization_1601[0][0]'
#                                                                  ]
#
#  conv2d_1602 (Conv2D)           (None, 71, 71, 192)  138240      ['activation_1601[0][0]']
#
#  batch_normalization_1602 (Batc  (None, 71, 71, 192)  576        ['conv2d_1602[0][0]']
#  hNormalization)
#
#  activation_1602 (Activation)   (None, 71, 71, 192)  0           ['batch_normalization_1602[0][0]'
#                                                                  ]
#
#  max_pooling2d_69 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_1602[0][0]']
#  )
#
#  conv2d_1606 (Conv2D)           (None, 35, 35, 64)   12288       ['max_pooling2d_69[0][0]']
#
#  batch_normalization_1606 (Batc  (None, 35, 35, 64)  192         ['conv2d_1606[0][0]']
#  hNormalization)
#
#  activation_1606 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1606[0][0]'
#                                                                  ]
#
#  conv2d_1604 (Conv2D)           (None, 35, 35, 48)   9216        ['max_pooling2d_69[0][0]']
#
#  conv2d_1607 (Conv2D)           (None, 35, 35, 96)   55296       ['activation_1606[0][0]']
#
#  batch_normalization_1604 (Batc  (None, 35, 35, 48)  144         ['conv2d_1604[0][0]']
#  hNormalization)
#
#  batch_normalization_1607 (Batc  (None, 35, 35, 96)  288         ['conv2d_1607[0][0]']
#  hNormalization)
#
#  activation_1604 (Activation)   (None, 35, 35, 48)   0           ['batch_normalization_1604[0][0]'
#                                                                  ]
#
#  activation_1607 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1607[0][0]'
#                                                                  ]
#
#  average_pooling2d_153 (Average  (None, 35, 35, 192)  0          ['max_pooling2d_69[0][0]']
#  Pooling2D)
#
#  conv2d_1603 (Conv2D)           (None, 35, 35, 64)   12288       ['max_pooling2d_69[0][0]']
#
#  conv2d_1605 (Conv2D)           (None, 35, 35, 64)   76800       ['activation_1604[0][0]']
#
#  conv2d_1608 (Conv2D)           (None, 35, 35, 96)   82944       ['activation_1607[0][0]']
#
#  conv2d_1609 (Conv2D)           (None, 35, 35, 32)   6144        ['average_pooling2d_153[0][0]']
#
#  batch_normalization_1603 (Batc  (None, 35, 35, 64)  192         ['conv2d_1603[0][0]']
#  hNormalization)
#
#  batch_normalization_1605 (Batc  (None, 35, 35, 64)  192         ['conv2d_1605[0][0]']
#  hNormalization)
#
#  batch_normalization_1608 (Batc  (None, 35, 35, 96)  288         ['conv2d_1608[0][0]']
#  hNormalization)
#
#  batch_normalization_1609 (Batc  (None, 35, 35, 32)  96          ['conv2d_1609[0][0]']
#  hNormalization)
#
#  activation_1603 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1603[0][0]'
#                                                                  ]
#
#  activation_1605 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1605[0][0]'
#                                                                  ]
#
#  activation_1608 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1608[0][0]'
#                                                                  ]
#
#  activation_1609 (Activation)   (None, 35, 35, 32)   0           ['batch_normalization_1609[0][0]'
#                                                                  ]
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_1603[0][0]',
#                                                                   'activation_1605[0][0]',
#                                                                   'activation_1608[0][0]',
#                                                                   'activation_1609[0][0]']
#
#  conv2d_1613 (Conv2D)           (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_1613 (Batc  (None, 35, 35, 64)  192         ['conv2d_1613[0][0]']
#  hNormalization)
#
#  activation_1613 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1613[0][0]'
#                                                                  ]
#
#  conv2d_1611 (Conv2D)           (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_1614 (Conv2D)           (None, 35, 35, 96)   55296       ['activation_1613[0][0]']
#
#  batch_normalization_1611 (Batc  (None, 35, 35, 48)  144         ['conv2d_1611[0][0]']
#  hNormalization)
#
#  batch_normalization_1614 (Batc  (None, 35, 35, 96)  288         ['conv2d_1614[0][0]']
#  hNormalization)
#
#  activation_1611 (Activation)   (None, 35, 35, 48)   0           ['batch_normalization_1611[0][0]'
#                                                                  ]
#
#  activation_1614 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1614[0][0]'
#                                                                  ]
#
#  average_pooling2d_154 (Average  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  Pooling2D)
#
#  conv2d_1610 (Conv2D)           (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_1612 (Conv2D)           (None, 35, 35, 64)   76800       ['activation_1611[0][0]']
#
#  conv2d_1615 (Conv2D)           (None, 35, 35, 96)   82944       ['activation_1614[0][0]']
#
#  conv2d_1616 (Conv2D)           (None, 35, 35, 64)   16384       ['average_pooling2d_154[0][0]']
#
#  batch_normalization_1610 (Batc  (None, 35, 35, 64)  192         ['conv2d_1610[0][0]']
#  hNormalization)
#
#  batch_normalization_1612 (Batc  (None, 35, 35, 64)  192         ['conv2d_1612[0][0]']
#  hNormalization)
#
#  batch_normalization_1615 (Batc  (None, 35, 35, 96)  288         ['conv2d_1615[0][0]']
#  hNormalization)
#
#  batch_normalization_1616 (Batc  (None, 35, 35, 64)  192         ['conv2d_1616[0][0]']
#  hNormalization)
#
#  activation_1610 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1610[0][0]'
#                                                                  ]
#
#  activation_1612 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1612[0][0]'
#                                                                  ]
#
#  activation_1615 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1615[0][0]'
#                                                                  ]
#
#  activation_1616 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1616[0][0]'
#                                                                  ]
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_1610[0][0]',
#                                                                   'activation_1612[0][0]',
#                                                                   'activation_1615[0][0]',
#                                                                   'activation_1616[0][0]']
#
#  conv2d_1620 (Conv2D)           (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_1620 (Batc  (None, 35, 35, 64)  192         ['conv2d_1620[0][0]']
#  hNormalization)
#
#  activation_1620 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1620[0][0]'
#                                                                  ]
#
#  conv2d_1618 (Conv2D)           (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_1621 (Conv2D)           (None, 35, 35, 96)   55296       ['activation_1620[0][0]']
#
#  batch_normalization_1618 (Batc  (None, 35, 35, 48)  144         ['conv2d_1618[0][0]']
#  hNormalization)
#
#  batch_normalization_1621 (Batc  (None, 35, 35, 96)  288         ['conv2d_1621[0][0]']
#  hNormalization)
#
#  activation_1618 (Activation)   (None, 35, 35, 48)   0           ['batch_normalization_1618[0][0]'
#                                                                  ]
#
#  activation_1621 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1621[0][0]'
#                                                                  ]
#
#  average_pooling2d_155 (Average  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  Pooling2D)
#
#  conv2d_1617 (Conv2D)           (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_1619 (Conv2D)           (None, 35, 35, 64)   76800       ['activation_1618[0][0]']
#
#  conv2d_1622 (Conv2D)           (None, 35, 35, 96)   82944       ['activation_1621[0][0]']
#
#  conv2d_1623 (Conv2D)           (None, 35, 35, 64)   18432       ['average_pooling2d_155[0][0]']
#
#  batch_normalization_1617 (Batc  (None, 35, 35, 64)  192         ['conv2d_1617[0][0]']
#  hNormalization)
#
#  batch_normalization_1619 (Batc  (None, 35, 35, 64)  192         ['conv2d_1619[0][0]']
#  hNormalization)
#
#  batch_normalization_1622 (Batc  (None, 35, 35, 96)  288         ['conv2d_1622[0][0]']
#  hNormalization)
#
#  batch_normalization_1623 (Batc  (None, 35, 35, 64)  192         ['conv2d_1623[0][0]']
#  hNormalization)
#
#  activation_1617 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1617[0][0]'
#                                                                  ]
#
#  activation_1619 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1619[0][0]'
#                                                                  ]
#
#  activation_1622 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1622[0][0]'
#                                                                  ]
#
#  activation_1623 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1623[0][0]'
#                                                                  ]
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_1617[0][0]',
#                                                                   'activation_1619[0][0]',
#                                                                   'activation_1622[0][0]',
#                                                                   'activation_1623[0][0]']
#
#  conv2d_1625 (Conv2D)           (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_1625 (Batc  (None, 35, 35, 64)  192         ['conv2d_1625[0][0]']
#  hNormalization)
#
#  activation_1625 (Activation)   (None, 35, 35, 64)   0           ['batch_normalization_1625[0][0]'
#                                                                  ]
#
#  conv2d_1626 (Conv2D)           (None, 35, 35, 96)   55296       ['activation_1625[0][0]']
#
#  batch_normalization_1626 (Batc  (None, 35, 35, 96)  288         ['conv2d_1626[0][0]']
#  hNormalization)
#
#  activation_1626 (Activation)   (None, 35, 35, 96)   0           ['batch_normalization_1626[0][0]'
#                                                                  ]
#
#  conv2d_1624 (Conv2D)           (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_1627 (Conv2D)           (None, 17, 17, 96)   82944       ['activation_1626[0][0]']
#
#  batch_normalization_1624 (Batc  (None, 17, 17, 384)  1152       ['conv2d_1624[0][0]']
#  hNormalization)
#
#  batch_normalization_1627 (Batc  (None, 17, 17, 96)  288         ['conv2d_1627[0][0]']
#  hNormalization)
#
#  activation_1624 (Activation)   (None, 17, 17, 384)  0           ['batch_normalization_1624[0][0]'
#                                                                  ]
#
#  activation_1627 (Activation)   (None, 17, 17, 96)   0           ['batch_normalization_1627[0][0]'
#                                                                  ]
#
#  max_pooling2d_70 (MaxPooling2D  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_1624[0][0]',
#                                                                   'activation_1627[0][0]',
#                                                                   'max_pooling2d_70[0][0]']
#
#  conv2d_1632 (Conv2D)           (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_1632 (Batc  (None, 17, 17, 128)  384        ['conv2d_1632[0][0]']
#  hNormalization)
#
#  activation_1632 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1632[0][0]'
#                                                                  ]
#
#  conv2d_1633 (Conv2D)           (None, 17, 17, 128)  114688      ['activation_1632[0][0]']
#
#  batch_normalization_1633 (Batc  (None, 17, 17, 128)  384        ['conv2d_1633[0][0]']
#  hNormalization)
#
#  activation_1633 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1633[0][0]'
#                                                                  ]
#
#  conv2d_1629 (Conv2D)           (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_1634 (Conv2D)           (None, 17, 17, 128)  114688      ['activation_1633[0][0]']
#
#  batch_normalization_1629 (Batc  (None, 17, 17, 128)  384        ['conv2d_1629[0][0]']
#  hNormalization)
#
#  batch_normalization_1634 (Batc  (None, 17, 17, 128)  384        ['conv2d_1634[0][0]']
#  hNormalization)
#
#  activation_1629 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1629[0][0]'
#                                                                  ]
#
#  activation_1634 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1634[0][0]'
#                                                                  ]
#
#  conv2d_1630 (Conv2D)           (None, 17, 17, 128)  114688      ['activation_1629[0][0]']
#
#  conv2d_1635 (Conv2D)           (None, 17, 17, 128)  114688      ['activation_1634[0][0]']
#
#  batch_normalization_1630 (Batc  (None, 17, 17, 128)  384        ['conv2d_1630[0][0]']
#  hNormalization)
#
#  batch_normalization_1635 (Batc  (None, 17, 17, 128)  384        ['conv2d_1635[0][0]']
#  hNormalization)
#
#  activation_1630 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1630[0][0]'
#                                                                  ]
#
#  activation_1635 (Activation)   (None, 17, 17, 128)  0           ['batch_normalization_1635[0][0]'
#                                                                  ]
#
#  average_pooling2d_156 (Average  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  Pooling2D)
#
#  conv2d_1628 (Conv2D)           (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_1631 (Conv2D)           (None, 17, 17, 192)  172032      ['activation_1630[0][0]']
#
#  conv2d_1636 (Conv2D)           (None, 17, 17, 192)  172032      ['activation_1635[0][0]']
#
#  conv2d_1637 (Conv2D)           (None, 17, 17, 192)  147456      ['average_pooling2d_156[0][0]']
#
#  batch_normalization_1628 (Batc  (None, 17, 17, 192)  576        ['conv2d_1628[0][0]']
#  hNormalization)
#
#  batch_normalization_1631 (Batc  (None, 17, 17, 192)  576        ['conv2d_1631[0][0]']
#  hNormalization)
#
#  batch_normalization_1636 (Batc  (None, 17, 17, 192)  576        ['conv2d_1636[0][0]']
#  hNormalization)
#
#  batch_normalization_1637 (Batc  (None, 17, 17, 192)  576        ['conv2d_1637[0][0]']
#  hNormalization)
#
#  activation_1628 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1628[0][0]'
#                                                                  ]
#
#  activation_1631 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1631[0][0]'
#                                                                  ]
#
#  activation_1636 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1636[0][0]'
#                                                                  ]
#
#  activation_1637 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1637[0][0]'
#                                                                  ]
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_1628[0][0]',
#                                                                   'activation_1631[0][0]',
#                                                                   'activation_1636[0][0]',
#                                                                   'activation_1637[0][0]']
#
#  conv2d_1642 (Conv2D)           (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_1642 (Batc  (None, 17, 17, 160)  480        ['conv2d_1642[0][0]']
#  hNormalization)
#
#  activation_1642 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1642[0][0]'
#                                                                  ]
#
#  conv2d_1643 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1642[0][0]']
#
#  batch_normalization_1643 (Batc  (None, 17, 17, 160)  480        ['conv2d_1643[0][0]']
#  hNormalization)
#
#  activation_1643 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1643[0][0]'
#                                                                  ]
#
#  conv2d_1639 (Conv2D)           (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_1644 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1643[0][0]']
#
#  batch_normalization_1639 (Batc  (None, 17, 17, 160)  480        ['conv2d_1639[0][0]']
#  hNormalization)
#
#  batch_normalization_1644 (Batc  (None, 17, 17, 160)  480        ['conv2d_1644[0][0]']
#  hNormalization)
#
#  activation_1639 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1639[0][0]'
#                                                                  ]
#
#  activation_1644 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1644[0][0]'
#                                                                  ]
#
#  conv2d_1640 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1639[0][0]']
#
#  conv2d_1645 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1644[0][0]']
#
#  batch_normalization_1640 (Batc  (None, 17, 17, 160)  480        ['conv2d_1640[0][0]']
#  hNormalization)
#
#  batch_normalization_1645 (Batc  (None, 17, 17, 160)  480        ['conv2d_1645[0][0]']
#  hNormalization)
#
#  activation_1640 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1640[0][0]'
#                                                                  ]
#
#  activation_1645 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1645[0][0]'
#                                                                  ]
#
#  average_pooling2d_157 (Average  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  Pooling2D)
#
#  conv2d_1638 (Conv2D)           (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_1641 (Conv2D)           (None, 17, 17, 192)  215040      ['activation_1640[0][0]']
#
#  conv2d_1646 (Conv2D)           (None, 17, 17, 192)  215040      ['activation_1645[0][0]']
#
#  conv2d_1647 (Conv2D)           (None, 17, 17, 192)  147456      ['average_pooling2d_157[0][0]']
#
#  batch_normalization_1638 (Batc  (None, 17, 17, 192)  576        ['conv2d_1638[0][0]']
#  hNormalization)
#
#  batch_normalization_1641 (Batc  (None, 17, 17, 192)  576        ['conv2d_1641[0][0]']
#  hNormalization)
#
#  batch_normalization_1646 (Batc  (None, 17, 17, 192)  576        ['conv2d_1646[0][0]']
#  hNormalization)
#
#  batch_normalization_1647 (Batc  (None, 17, 17, 192)  576        ['conv2d_1647[0][0]']
#  hNormalization)
#
#  activation_1638 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1638[0][0]'
#                                                                  ]
#
#  activation_1641 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1641[0][0]'
#                                                                  ]
#
#  activation_1646 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1646[0][0]'
#                                                                  ]
#
#  activation_1647 (Activation)   (None, 17, 17, 192)  0           ['batch_normalization_1647[0][0]'
#                                                                  ]
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_1638[0][0]',
#                                                                   'activation_1641[0][0]',
#                                                                   'activation_1646[0][0]',
#                                                                   'activation_1647[0][0]']
#
#  conv2d_1652 (Conv2D)           (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_1652 (Batc  (None, 17, 17, 160)  480        ['conv2d_1652[0][0]']
#  hNormalization)
#
#  activation_1652 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1652[0][0]'
#                                                                  ]
#
#  conv2d_1653 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1652[0][0]']
#
#  batch_normalization_1653 (Batc  (None, 17, 17, 160)  480        ['conv2d_1653[0][0]']
#  hNormalization)
#
#  activation_1653 (Activation)   (None, 17, 17, 160)  0           ['batch_normalization_1653[0][0]'
#                                                                  ]
#
#  conv2d_1649 (Conv2D)           (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_1654 (Conv2D)           (None, 17, 17, 160)  179200      ['activation_1653[0][0]']
#
#  batch_normalization_1649 (Batc  (None, 17, 17, 160)  480        ['conv2d_1649[0][0]']
#  hNormalization)
# ...
#  conv2d_1677 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1675[0][0]']
#
#  conv2d_1680 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1679[0][0]']
#
#  conv2d_1681 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1679[0][0]']
#
#  average_pooling2d_160 (Average  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  Pooling2D)
#
#  conv2d_1674 (Conv2D)           (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_1676 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1676[0][0]']
#  hNormalization)
#
#  batch_normalization_1677 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1677[0][0]']
#  hNormalization)
#
#  batch_normalization_1680 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1680[0][0]']
#  hNormalization)
#
#  batch_normalization_1681 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1681[0][0]']
#  hNormalization)
#
#  conv2d_1682 (Conv2D)           (None, 8, 8, 192)    245760      ['average_pooling2d_160[0][0]']
#
#  batch_normalization_1674 (Batc  (None, 8, 8, 320)   960         ['conv2d_1674[0][0]']
#  hNormalization)
#
#  activation_1676 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1676[0][0]'
#                                                                  ]
#
#  activation_1677 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1677[0][0]'
#                                                                  ]
#
#  activation_1680 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1680[0][0]'
#                                                                  ]
#
#  activation_1681 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1681[0][0]'
#                                                                  ]
#
#  batch_normalization_1682 (Batc  (None, 8, 8, 192)   576         ['conv2d_1682[0][0]']
#  hNormalization)
#
#  activation_1674 (Activation)   (None, 8, 8, 320)    0           ['batch_normalization_1674[0][0]'
#                                                                  ]
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_1676[0][0]',
#                                                                   'activation_1677[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 8, 8, 768)    0           ['activation_1680[0][0]',
#                                                                   'activation_1681[0][0]']
#
#  activation_1682 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1682[0][0]'
#                                                                  ]
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_1674[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_34[0][0]',
#                                                                   'activation_1682[0][0]']
#
#  conv2d_1687 (Conv2D)           (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_1687 (Batc  (None, 8, 8, 448)   1344        ['conv2d_1687[0][0]']
#  hNormalization)
#
#  activation_1687 (Activation)   (None, 8, 8, 448)    0           ['batch_normalization_1687[0][0]'
#                                                                  ]
#
#  conv2d_1684 (Conv2D)           (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_1688 (Conv2D)           (None, 8, 8, 384)    1548288     ['activation_1687[0][0]']
#
#  batch_normalization_1684 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1684[0][0]']
#  hNormalization)
#
#  batch_normalization_1688 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1688[0][0]']
#  hNormalization)
#
#  activation_1684 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1684[0][0]'
#                                                                  ]
#
#  activation_1688 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1688[0][0]'
#                                                                  ]
#
#  conv2d_1685 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1684[0][0]']
#
#  conv2d_1686 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1684[0][0]']
#
#  conv2d_1689 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1688[0][0]']
#
#  conv2d_1690 (Conv2D)           (None, 8, 8, 384)    442368      ['activation_1688[0][0]']
#
#  average_pooling2d_161 (Average  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  Pooling2D)
#
#  conv2d_1683 (Conv2D)           (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_1685 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1685[0][0]']
#  hNormalization)
#
#  batch_normalization_1686 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1686[0][0]']
#  hNormalization)
#
#  batch_normalization_1689 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1689[0][0]']
#  hNormalization)
#
#  batch_normalization_1690 (Batc  (None, 8, 8, 384)   1152        ['conv2d_1690[0][0]']
#  hNormalization)
#
#  conv2d_1691 (Conv2D)           (None, 8, 8, 192)    393216      ['average_pooling2d_161[0][0]']
#
#  batch_normalization_1683 (Batc  (None, 8, 8, 320)   960         ['conv2d_1683[0][0]']
#  hNormalization)
#
#  activation_1685 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1685[0][0]'
#                                                                  ]
#
#  activation_1686 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1686[0][0]'
#                                                                  ]
#
#  activation_1689 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1689[0][0]'
#                                                                  ]
#
#  activation_1690 (Activation)   (None, 8, 8, 384)    0           ['batch_normalization_1690[0][0]'
#                                                                  ]
#
#  batch_normalization_1691 (Batc  (None, 8, 8, 192)   576         ['conv2d_1691[0][0]']
#  hNormalization)
#
#  activation_1683 (Activation)   (None, 8, 8, 320)    0           ['batch_normalization_1683[0][0]'
#                                                                  ]
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_1685[0][0]',
#                                                                   'activation_1686[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 8, 8, 768)    0           ['activation_1689[0][0]',
#                                                                   'activation_1690[0][0]']
#
#  activation_1691 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1691[0][0]'
#                                                                  ]
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_1683[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_35[0][0]',
#                                                                   'activation_1691[0][0]']
#
#  global_average_pooling2d_17 (G  (None, 2048)        0           ['mixed10[0][0]']
#  lobalAveragePooling2D)
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 21,768,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# Generating Bottleneck Dataset... this may take some minutes.
# Found 450 images belonging to 3 classes.
# Done generating Bottleneck Dataset
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_27 (InputLayer)       [(None, 2048)]            0
#
#  classifier (Dense)          (None, 3)                 6147
#
# =================================================================
# Total params: 6,147
# Trainable params: 6,147
# Non-trainable params: 0
# _________________________________________________________________
# 5000/5000 [==============================] - 7s 1ms/step - loss: 0.0546 - accuracy: 0.9936
